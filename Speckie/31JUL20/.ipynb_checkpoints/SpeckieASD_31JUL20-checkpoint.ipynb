# %%
import LoadData

# %%
import pandas as pd

# %%
calfile = '/g/data/up71/projects/CalVal_Phase2/FLAME/CALIBRATION/RadCalCoeff_GT08_.csv'

# %%
alldata = LoadData.load_from_dir('/g/data/up71/projects/CalVal_Phase2/Speckie/31JUL20/se_31_7_2020/', calfile)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9bdbdbedff1e> in <module>
# ----> 1 alldata = LoadData.load_from_dir('/g/data/up71/projects/CalVal_Phase2/Speckie/31JUL20/se_31_7_2020/', calfile)
#
# /g/data4/up71/projects/CalVal_Phase2/Speckie/31JUL20/LoadData.py in load_from_dir(indir, calfile)
#     106         infile = indir + name
#     107
# --> 108         df = load_spectrum_to_df(infile, calfile)
#     109         df['SpecNum'] = count
#     110         count +=1
#
# /g/data4/up71/projects/CalVal_Phase2/Speckie/31JUL20/LoadData.py in load_spectrum_to_df(infile, calfile)
#      54     fdl,err = p2.communicate()
#      55
# ---> 56     firstDataLine = int(fdl)
#      57
#      58     date_str, int_time, time_str = extract_metadata(infile)
#
# ValueError: invalid literal for int() with base 10: b''

# %%
alldata
# Out:
#              Rad_Ref  Rad_Target  CalData                     filename  \
# Wavelength
# 350.0       0.006875    0.006875      NaN  SR-3500_SN20680T1_00000.sed
# 351.0       0.007093    0.007093      NaN  SR-3500_SN20680T1_00000.sed
# 352.0       0.007292    0.007292      NaN  SR-3500_SN20680T1_00000.sed
# 353.0       0.007462    0.007462      NaN  SR-3500_SN20680T1_00000.sed
# 354.0       0.007609    0.007609      NaN  SR-3500_SN20680T1_00000.sed
# ...              ...         ...      ...                          ...
# 2496.0           NaN    0.000328      NaN  SR-3500_SN20680T1_00007.sed
# 2497.0           NaN    0.000325      NaN  SR-3500_SN20680T1_00007.sed
# 2498.0           NaN    0.000314      NaN  SR-3500_SN20680T1_00007.sed
# 2499.0           NaN    0.000295      NaN  SR-3500_SN20680T1_00007.sed
# 2500.0           NaN    0.000274      NaN  SR-3500_SN20680T1_00007.sed
#
#                     date_saved  IntTime  SpecNum
# Wavelength
# ...

# %%
df
